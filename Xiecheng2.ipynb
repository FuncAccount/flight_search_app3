# %%
import requests
import json
from prettytable import PrettyTable
import pandas as pd
import time
pd.set_option('display.max_rows', None)
headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36",
        "Content-Type": "application/json"  # 声明文本类型为 json 格式
        # 'Cookie': 'your_cookie_here'  # Optional: Include if needed
    }

    # Assuming 'city' dictionary contains mappings of city names to their codes
city = {
    '上海': 'SHA',
    '北京': 'BJS',
    '广州': 'CAN',
    '深圳': 'SZX',
    '重庆': 'CKG',
    '天津': 'TSN',
    '成都': 'CTU',
    '武汉': 'WUH',
    '杭州': 'HGH',
    '南京': 'NKG',
    '西安': 'SIA',
    '郑州': 'CGO',
    '长沙': 'CSX',
    '青岛': 'TAO',
    '大连': 'DLC',
    '沈阳': 'SHE',
    '济南': 'TNA',
    '宁波': 'NGB',
    '厦门': 'XMN',
    '长春': 'CGQ',
    '昆明': 'KMG',
    '南宁': 'NNG',
    '合肥': 'HFE',
    '呼和浩特': 'HET',
    '哈尔滨': 'HRB',
    '太原': 'TYN',
    '兰州': 'LHW',
    '福州': 'FOC',
    '海口': 'HAK',
    '贵阳': 'KWE',
    '南昌': 'KHN',
    '乌鲁木齐': 'URC',
    '克拉玛依': 'KRY',
    '丽江': 'LJG',
    '哈密': 'HMI',
    '拉萨': 'LXA',
    '银川': 'INC',
    '西宁': 'XNN',
    '兰州': 'LHW',
    '乌鲁木齐': 'URC',
    '临沂': 'LYI',
    '东营': 'DOY',
    '威海': 'WEH',
    '泉州': 'JJN',
    '洛阳': 'LYA',
    '昭通': 'ZAT',
    '吉安': 'KNC',
    '营口': 'YKH',
    '曲靖': 'JUZ',
    '通化': 'TNH'
# '上海': 'SHA',
#     '北京': 'BJS',
#     '广州': 'CAN',
#     '深圳': 'SZX',
#     '重庆': 'CKG',
#     '天津': 'TSN',
#     '成都': 'CTU',
#     '武汉': 'WUH',
#     '杭州': 'HGH',
#     '南京': 'NKG',
#     '西安': 'SIA',
#     '郑州': 'CGO',
#     '长沙': 'CSX',
#     '青岛': 'TAO',
#     '大连': 'DLC',
#     '沈阳': 'SHE',
#     '济南': 'TNA',
#     '宁波': 'NGB',
#     '厦门': 'XMN',
#     '长春': 'CGQ',
#     '昆明': 'KMG',
#     '南宁': 'NNG',
#     '合肥': 'HFE',
#     '呼和浩特': 'HET',
#     '哈尔滨': 'HRB',
#     '太原': 'TYN',
#     '兰州': 'LHW',
#     '福州': 'FOC',
#     '海口': 'HAK',
#     '贵阳': 'KWE',
#     '南昌': 'KHN',
#     '乌鲁木齐': 'URC',
#     '克拉玛依': 'KRY',
#     '丽江': 'LJG',
#     '哈密': 'HMI',
#     '拉萨': 'LXA',
#     '银川': 'INC',
#     '西宁': 'XNN',
#     '兰州': 'LHW',
#     '乌鲁木齐': 'URC',
#     '临沂': 'LYI',
#     '东营': 'DOY',
#     '威海': 'WEH',
#     '泉州': 'JJN',
#     '洛阳': 'LYA',
#     '昭通': 'ZAT',
#     '吉安': 'KNC',
#     '营口': 'YKH',
#     '曲靖': 'JUZ',
#     '通化': 'TNH',
#     '常州': 'CZX',
#     '徐州': 'XUZ',
#     '拉萨': 'LXA',
#     '邢台': 'XNT',
#     '莆田': 'FUG',
#     '菏泽': 'HEB',
#     '赣州': 'KOW',
#     '舟山': 'HSN',
#     '景德镇': 'JDZ',
#     '宿迁': 'SZV',
#     '襄阳': 'XFN',
#     '绵阳': 'MIG',
#     '九江': 'JIU',
#     '岳阳': 'YYA',
#     '阜阳': 'FUG',
#     '丹东': 'DDG',
#     '扬州': 'YTY',
#     '佳木斯': 'JMU',
#     '泸州': 'LZO',
#     '黄山': 'TXN',
#     '铜仁': 'TEN',
#     '宜宾': 'YBP',
#     '宜春': 'YIC',
#     '赤峰': 'CIF',
#     '锡林浩特': 'XIL',
#     '亳州': 'AQG',
#     '黔江': 'JIQ',
#     '黔东南': 'KJH',
#     '鸡西': 'JXA',
#     '塔城': 'TCG'
    }

# %%
def xiecheng(dcity, acity, date):
    date = date[0:4] + '-' + date[4:6] + '-' + date[6:8]
    headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36",
            "Content-Type": "application/json"  # 声明文本类型为 json 格式
            # 'Cookie': 'your_cookie_here'  # Optional: Include if needed
        }

        # Assuming 'city' dictionary contains mappings of city names to their codes
    city = {
        "北京": "BJS",  # Beijing
        "上海": "SHA",  # Shanghai
        "广州": "CAN",  # Guangzhou
        "深圳": "SZX",  # Shenzhen
        "成都": "CTU",  # Chengdu
        "西安": "XIY",  # Xi'an
        "重庆": "CKG",  # Chongqing
        "杭州": "HGH",  # Hangzhou
        "武汉": "WUH",  # Wuhan
        "南京": "NKG",  # Nanjing
        "苏州": "SZV",  # Suzhou
        "天津": "TSN",  # Tianjin
        "昆明": "KMG",  # Kunming
        "大连": "DLC",  # Dalian
        "青岛": "TAO",  # Qingdao
        "厦门": "XMN",  # Xiamen
        "沈阳": "SHE",  # Shenyang
        "哈尔滨": "HRB",  # Harbin
        "长沙": "CSX",  # Changsha
        "郑州": "CGO",  # Zhengzhou
        "济南": "TNA",  # Jinan
        "福州": "FOC",  # Fuzhou
        "贵阳": "KWE",  # Guiyang
        "石家庄": "SJW",  # Shijiazhuang
        "长春": "CGQ",  # Changchun
        "南昌": "KHN",  # Nanchang
        "乌鲁木齐": "URC",  # Urumqi
        "合肥": "HFE",  # Hefei
        "南宁": "NNG",  # Nanning
        "海口": "HAK",  # Haikou
        "兰州": "LHW",  # Lanzhou
        "银川": "INC",  # Yinchuan
        "西宁": "XNN",  # Xining
        "太原": "TYN",  # Taiyuan
        "呼和浩特": "HET",  # Hohhot
    }
    url = 'https://flights.ctrip.com/itinerary/api/12808/products'
    request_payload = {"flightWay": "Oneway",
                       "army": "false",
                       "classType": "ALL",
                       "hasChild": 'false',
                       "hasBaby": 'false',
                       "searchIndex": 1,
                       "portingToken": "3fec6a5a249a44faba1f245e61e2af88",
                       "airportParams": [
                           {"dcity": city.get(dcity), "acity": city.get(acity), "dcityname": dcity, "acityname": acity,
                            "date": date}]}

    response = requests.post(url, data=json.dumps(request_payload), headers=headers).text
    # print(json.loads(response))
    routeList = json.loads(response)["data"].get('routeList')
    table = PrettyTable(["LowestPrice", "Airline", "FlightNumber", "Legs","PunctualityRate", "ArrivalDate", "DepartureDate"])
    
    for route in routeList:
        if len(route.get('legs')) != 0:
            info = {}
            legs = route.get('legs')[0]
            flight = legs.get('flight')
            info['LowestPrice'] = legs.get('characteristic').get('lowestPrice')
            info['Airline'] = flight.get('airlineName')
            info['FlightNumber'] = flight.get('flightNumber')
            leg_list = []
            for leg in route.get('legs'):
                each_flight = leg.get('flight')
                leg_city = each_flight.get('arrivalAirportInfo').get('cityName')
                leg_airport = each_flight.get('arrivalAirportInfo').get('airportName')
                leg_list.append(leg_city+leg_airport)
            info['Legs'] = leg_list
            info['PunctualityRate'] = flight.get('punctualityRate')
            info['ArrivalDate'] = flight.get('arrivalDate')[-8:-3]
            info['DepartureDate'] = flight.get('departureDate')[-8:-3]
            
            
            

            table.add_row(info.values())


    print(dcity, '------->', acity, date)
    # Step 1: Extract the column headers
    headers = table.field_names

    # Step 2: Extract the rows directly
    rows = [list(row) for row in table._rows]

    # Step 3: Create DataFrame
    df = pd.DataFrame(rows, columns=headers)

    # display(df)
    return df
if __name__ == "__main__":
#     # dcity = input('请输入起点： ')
#     # acity = input('请输入终点： ')
#     # date = input('请输入出行日期： ')
    dcity = '深圳'
    acity = '厦门'
    date =  '20231210'

    display(xiecheng(dcity, acity, date))
# Out:
# 深圳 -------> 厦门 2023-12-10
#    LowestPrice Airline FlightNumber                   Legs PunctualityRate  \
# 0         None    东方航空       MU5760   [昆明长水国际机场, 厦门高崎国际机场]             90%
# 1         None    东方航空       MU5760   [昆明长水国际机场, 厦门高崎国际机场]             90%
# 2         None    东方航空       MU5760   [昆明长水国际机场, 厦门高崎国际机场]             90%
# 3         None    四川航空       3U8272   [昆明长水国际机场, 厦门高崎国际机场]
# 4         None    南方航空       CZ5759   [昆明长水国际机场, 厦门高崎国际机场]             97%
# 5         None    南方航空       CZ3451   [昆明长水国际机场, 厦门高崎国际机场]            100%
# 6         None    东方航空       MU2952     [常州奔牛机场, 厦门高崎国际机场]             87%
# 7         None    东方航空       MU2952     [常州奔牛机场, 厦门高崎国际机场]             87%
# 8         None    东方航空       MU2830   [南京禄口国际机场, 厦门高崎国际机场]
# 9         None    东方航空       MU2888   [南京禄口国际机场, 厦门高崎国际机场]             63%
# 10        None    东方航空       MU2888   [南京禄口国际机场, 厦门高崎国际机场]             63%
# 11        None    东方航空       MU5342   [上海浦东国际机场, 厦门高崎国际机场]             83%
# 12        None    上海航空       FM9332   [上海虹桥国际机场, 厦门高崎国际机场]             77%
# 13        None    海南航空       HU7024   [海口美兰国际机场, 厦门高崎国际机场]             73%
# 14        None    东方航空       MU5334   [上海虹桥国际机场, 厦门高崎国际机场]            100%
# 15        None    深圳航空       ZH8209  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 16        None    海南航空       HU7773  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 17        None    南方航空       CZ8446   [武汉天河国际机场, 厦门高崎国际机场]             97%
# 18        None    南方航空       CZ3673  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 19        None    深圳航空       ZH9895   [合肥新桥国际机场, 厦门高崎国际机场]             90%
# 20        None    南方航空       CZ8446   [武汉天河国际机场, 厦门高崎国际机场]             97%
# 21        None    南方航空       CZ3673  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 22        None    深圳航空       ZH8209  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 23        None    海南航空       HU7026   [海口美兰国际机场, 厦门高崎国际机场]             97%
# 24        None    南方航空       CZ6443   [海口美兰国际机场, 厦门高崎国际机场]            100%
# 25        None    深圳航空       ZH9893   [合肥新桥国际机场, 厦门高崎国际机场]            100%
# 26        None    南方航空       CZ3435  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 27        None    南方航空       CZ5457   [武汉天河国际机场, 厦门高崎国际机场]             93%
# 28        None    南方航空       CZ5457   [武汉天河国际机场, 厦门高崎国际机场]             93%
# 29        None    多彩航空       GY7238  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             87%
# 30        None    南方航空       CZ3435  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 31        None    南方航空       CZ5378  [贵阳龙洞堡国际机场, 厦门高崎国际机场]            100%
# 32        None    南方航空       CZ6372  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             87%
# 33        None    海南航空       HU7773  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 34        None    春秋航空       9C7039   [武汉天河国际机场, 厦门高崎国际机场]            100%
# 35        None    南方航空       CZ5378  [贵阳龙洞堡国际机场, 厦门高崎国际机场]            100%
# 36        None    南方航空       CZ3435  [贵阳龙洞堡国际机场, 厦门高崎国际机场]             97%
# 37        None    南方航空       CZ8446   [武汉天河国际机场, 厦门高崎国际机场]             97%
# 38        None    南方航空       CZ5457   [武汉天河国际机场, 厦门高崎国际机场]             93%
# 39        None    春秋航空       9C7039   [武汉天河国际机场, 厦门高崎国际机场]            100%
# 40        None    海南航空       HU7755   [武汉天河国际机场, 厦门高崎国际机场]             97%
# 41        None    南方航空       CZ5457   [武汉天河国际机场, 厦门高崎国际机场]             93%
#
#    ArrivalDate DepartureDate
# 0        01:05         22:30
# 1        01:05         22:30
# 2        01:05         22:30
# 3        12:30         09:55
# 4        00:05         20:00
# 5        16:35         14:00
# 6        01:50         23:30
# 7        01:50         23:30
# 8        01:40         23:25
# 9        20:10         18:05
# 10       20:10         18:05
# 11       15:25         13:05
# 12       14:30         12:30
# 13       01:05         23:35
# 14       11:30         09:30
# 15       10:15         07:50
# 16       19:20         17:20
# 17       15:00         13:05
# 18       09:55         08:05
# 19       17:10         14:45
# 20       15:00         13:05
# 21       09:55         08:05
# 22       10:15         07:50
# 23       15:15         13:45
# 24       07:55         06:40
# 25       13:25         11:10
# 26       16:35         14:45
# 27       17:50         16:00
# 28       17:50         16:00
# 29       23:55         20:25
# 30       16:35         14:45
# 31       12:45         10:50
# 32       00:20         22:25
# 33       19:20         17:20
# 34       11:45         09:45
# 35       12:45         10:50
# 36       16:35         14:45
# 37       15:00         13:05
# 38       17:50         16:00
# 39       11:45         09:45
# 40       09:00         07:00
# 41       17:50         16:00

# %%
def xiecheng2(dcity, acity, date):
    date = date[0:4] + '-' + date[4:6] + '-' + date[6:8]
    headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36",
            "Content-Type": "application/json"  # 声明文本类型为 json 格式
            # 'Cookie': 'your_cookie_here'  # Optional: Include if needed
        }

        # Assuming 'city' dictionary contains mappings of city names to their codes
    city = {
    '上海': 'SHA',
    '北京': 'BJS',
    '广州': 'CAN',
    '深圳': 'SZX',
    '重庆': 'CKG',
    '天津': 'TSN',
    '成都': 'CTU',
    '武汉': 'WUH',
    '杭州': 'HGH',
    '南京': 'NKG',
    '西安': 'SIA',
    '郑州': 'CGO',
    '长沙': 'CSX',
    '青岛': 'TAO',
    '大连': 'DLC',
    '沈阳': 'SHE',
    '济南': 'TNA',
    '宁波': 'NGB',
    '厦门': 'XMN',
    '长春': 'CGQ',
    '昆明': 'KMG',
    '南宁': 'NNG',
    '合肥': 'HFE',
    '呼和浩特': 'HET',
    '哈尔滨': 'HRB',
    '太原': 'TYN',
    '兰州': 'LHW',
    '福州': 'FOC',
    '海口': 'HAK',
    '贵阳': 'KWE',
    '南昌': 'KHN',
    '乌鲁木齐': 'URC',
    '克拉玛依': 'KRY',
    '丽江': 'LJG',
    '哈密': 'HMI',
    '拉萨': 'LXA',
    '银川': 'INC',
    '西宁': 'XNN',
    '兰州': 'LHW',
    '乌鲁木齐': 'URC',
    '临沂': 'LYI',
    '东营': 'DOY',
    '威海': 'WEH',
    '泉州': 'JJN',
    '洛阳': 'LYA',
    '昭通': 'ZAT',
    '吉安': 'KNC',
    '营口': 'YKH',
    '曲靖': 'JUZ',
    '通化': 'TNH'
# '上海': 'SHA',
#     '北京': 'BJS',
#     '广州': 'CAN',
#     '深圳': 'SZX',
#     '重庆': 'CKG',
#     '天津': 'TSN',
#     '成都': 'CTU',
#     '武汉': 'WUH',
#     '杭州': 'HGH',
#     '南京': 'NKG',
#     '西安': 'SIA',
#     '郑州': 'CGO',
#     '长沙': 'CSX',
#     '青岛': 'TAO',
#     '大连': 'DLC',
#     '沈阳': 'SHE',
#     '济南': 'TNA',
#     '宁波': 'NGB',
#     '厦门': 'XMN',
#     '长春': 'CGQ',
#     '昆明': 'KMG',
#     '南宁': 'NNG',
#     '合肥': 'HFE',
#     '呼和浩特': 'HET',
#     '哈尔滨': 'HRB',
#     '太原': 'TYN',
#     '兰州': 'LHW',
#     '福州': 'FOC',
#     '海口': 'HAK',
#     '贵阳': 'KWE',
#     '南昌': 'KHN',
#     '乌鲁木齐': 'URC',
#     '克拉玛依': 'KRY',
#     '丽江': 'LJG',
#     '哈密': 'HMI',
#     '拉萨': 'LXA',
#     '银川': 'INC',
#     '西宁': 'XNN',
#     '兰州': 'LHW',
#     '乌鲁木齐': 'URC',
#     '临沂': 'LYI',
#     '东营': 'DOY',
#     '威海': 'WEH',
#     '泉州': 'JJN',
#     '洛阳': 'LYA',
#     '昭通': 'ZAT',
#     '吉安': 'KNC',
#     '营口': 'YKH',
#     '曲靖': 'JUZ',
#     '通化': 'TNH',
#     '常州': 'CZX',
#     '徐州': 'XUZ',
#     '拉萨': 'LXA',
#     '邢台': 'XNT',
#     '莆田': 'FUG',
#     '菏泽': 'HEB',
#     '赣州': 'KOW',
#     '舟山': 'HSN',
#     '景德镇': 'JDZ',
#     '宿迁': 'SZV',
#     '襄阳': 'XFN',
#     '绵阳': 'MIG',
#     '九江': 'JIU',
#     '岳阳': 'YYA',
#     '阜阳': 'FUG',
#     '丹东': 'DDG',
#     '扬州': 'YTY',
#     '佳木斯': 'JMU',
#     '泸州': 'LZO',
#     '黄山': 'TXN',
#     '铜仁': 'TEN',
#     '宜宾': 'YBP',
#     '宜春': 'YIC',
#     '赤峰': 'CIF',
#     '锡林浩特': 'XIL',
#     '亳州': 'AQG',
#     '黔江': 'JIQ',
#     '黔东南': 'KJH',
#     '鸡西': 'JXA',
#     '塔城': 'TCG'
    }
    url = 'https://flights.ctrip.com/itinerary/api/12808/products'

    request_payload = {"flightWay": "Oneway",
                        "army": "false",
                        "classType": "ALL",
                        "hasChild": 'false',
                        "hasBaby": 'false',
                        "searchIndex": 1,
                        "portingToken": "3fec6a5a249a44faba1f245e61e2af88",
                        "airportParams": [
                            {"dcity": city.get(dcity), "acity": city.get(acity), "dcityname": dcity, "acityname": acity,
                                "date": date}]}

    response = requests.post(url, data=json.dumps(request_payload), headers=headers).text
    # print(json.loads(response))
    try:
        routeList = json.loads(response)["data"].get('routeList')
    except:
        print('route error' ,dcity, '-',acity )
        return None 
    table2 = PrettyTable(["LowestPrice", "Airline", "FlightNumber", "Legs","PunctualityRate", "ArrivalDate", "DepartureDate"])
    
    if routeList != None:
        for route in routeList:
            if len(route.get('legs')) !=0:
                info = {}
                legs = route.get('legs')[0]
                flight = legs.get('flight')
                info['LowestPrice'] = legs.get('characteristic').get('lowestPrice')
                info['Airline'] = flight.get('airlineName')
                info['FlightNumber'] = flight.get('flightNumber')
                
                
        ###############################################################################    
                leg_list = []
                total_price = 0 # This entire block is for flights with transit. So although total_price might seems confusing. It is used to add all the price from each leg together
                for leg in route.get('legs'):
                    each_flight = leg.get('flight')
                    each_cabin = leg.get('cabins')
                    leg_city = each_flight.get('arrivalAirportInfo').get('cityName')
                    leg_airport = each_flight.get('arrivalAirportInfo').get('airportName')
                    leg_list.append(leg_city+leg_airport)
                    
                    for cabin in each_cabin:  # Iterate through each cabin in the leg
                        cabin_price_info = cabin.get('price')  # cabin_price_info is a dictionary

                        if cabin_price_info and 'price' in cabin_price_info:
                            cabin_price = cabin_price_info.get('price')  # Get the price for the cabin
                            total_price += cabin_price  # Sum up the prices

                if len(route.get('legs')) > 1:
                    info['LowestPrice'] = total_price
    ##################################################################################
                info['Legs'] = leg_list

                info['PunctualityRate'] = flight.get('punctualityRate')
                info['ArrivalDate'] = flight.get('arrivalDate')[-8:-3]
                info['DepartureDate'] = flight.get('departureDate')[-8:-3]

                table2.add_row(info.values())
    else:
        print('no flight route on', dcity, '-',acity)



    print(dcity, '------->', acity, date)
    # print(table2)
    filename = dcity+acity+date+".txt"
    with open(filename, 'w', encoding='utf-8') as file:
        # Convert routeList to a pretty formatted string and write to the file
        pretty_route_list = json.dumps(routeList, indent=4, ensure_ascii=False)
        file.write(pretty_route_list)
    
    # Step 1: Extract the column headers
    headers = table2.field_names

    # Step 2: Extract the rows directly
    rows = [list(row) for row in table2._rows]

    # Step 3: Create DataFrame
    df = pd.DataFrame(rows, columns=headers)

    # display(df)
    return df

# %%
if __name__ == "__main__":
    # dcity = input('请输入起点： ')
    # acity = input('请输入终点： ')
    # date = input('请输入出行日期： ')
    dcity = '深圳'
    acity = '成都'
    date =  '20231209'
    # temp_df0 = xiecheng(dcity, acity, date)
    # temp_df0 = temp_df0.sort_values(by='LowestPrice')

    all_city = list(city.keys())
    if dcity in all_city:
        all_city.remove(dcity)
    
    temp_df = None
    
    for _city in all_city:
        temp_dfx = xiecheng2(dcity, _city, date)
        if isinstance(temp_dfx, pd.DataFrame):
            if temp_df is None:
                temp_df = temp_dfx
            else:
                temp_df = pd.concat([temp_df, temp_dfx], axis=0, ignore_index=True)
        else:
            pass
        time.sleep(1)
    # print(temp_df)
    filtered_df = temp_df[temp_df['Legs'].apply(lambda x: any(acity in leg for leg in x[:-1]))]
    filtered_df = filtered_df.sort_values(by='LowestPrice')


    filtered_df0 = temp_df[temp_df['Legs'].apply(lambda x: len(x) == 1 and acity in x[0])]
    filtered_df0 = filtered_df0.sort_values(by='LowestPrice')
    # 正常机票
    print('正常机票')
    display(filtered_df0)
    #跳票机票
    print('跳票机票')
    display(filtered_df)
# Out:
# 深圳 -------> 上海 2023-12-09
# 深圳 -------> 北京 2023-12-09
# no flight route on 深圳 - 广州
# 深圳 -------> 广州 2023-12-09
# 深圳 -------> 重庆 2023-12-09
# 深圳 -------> 天津 2023-12-09
# 深圳 -------> 成都 2023-12-09
# 深圳 -------> 武汉 2023-12-09
# 深圳 -------> 杭州 2023-12-09
# 深圳 -------> 南京 2023-12-09
# 深圳 -------> 西安 2023-12-09
# 深圳 -------> 郑州 2023-12-09
# 深圳 -------> 长沙 2023-12-09
# 深圳 -------> 青岛 2023-12-09
# 深圳 -------> 大连 2023-12-09
# 深圳 -------> 沈阳 2023-12-09
# 深圳 -------> 济南 2023-12-09
# 深圳 -------> 宁波 2023-12-09
# 深圳 -------> 厦门 2023-12-09
# 深圳 -------> 长春 2023-12-09
# 深圳 -------> 昆明 2023-12-09
# 深圳 -------> 南宁 2023-12-09
# 深圳 -------> 合肥 2023-12-09
# 深圳 -------> 呼和浩特 2023-12-09
# 深圳 -------> 哈尔滨 2023-12-09
# 深圳 -------> 太原 2023-12-09
# 深圳 -------> 兰州 2023-12-09
# 深圳 -------> 福州 2023-12-09
# 深圳 -------> 海口 2023-12-09
# 深圳 -------> 贵阳 2023-12-09
# 深圳 -------> 南昌 2023-12-09
# 深圳 -------> 乌鲁木齐 2023-12-09
# 深圳 -------> 克拉玛依 2023-12-09
# 深圳 -------> 丽江 2023-12-09
# 深圳 -------> 哈密 2023-12-09
# 深圳 -------> 拉萨 2023-12-09
# 深圳 -------> 银川 2023-12-09
# 深圳 -------> 西宁 2023-12-09
# 深圳 -------> 临沂 2023-12-09
# 深圳 -------> 东营 2023-12-09
# 深圳 -------> 威海 2023-12-09
# 1081             87%       17:10         14:35
# 1660             97%       21:55         19:25
# 1070             97%       10:20         07:55
# 1668             97%       11:10         08:40
# 730              97%       11:10         08:40
# 1075            100%       15:45         13:15
# 1696            100%       23:05         20:30
# 1698             97%       23:45         21:05
# 1558             77%       16:00         13:35
# 1557             67%       14:30         12:05
# 1649             97%       23:45         21:30
# 356              97%       10:20         07:55
# 1079             77%       16:00         13:35
# 1268             67%       14:30         12:05
# 1019             67%       14:30         12:05
# 1020             77%       16:00         13:35
# 1409            100%       15:45         13:15
# 1127             97%       10:20         07:55
# 1397             67%       14:30         12:05
# 1410             97%       23:45         21:05
# 1405            100%       23:05         20:30
# 1428             97%       23:45         21:30
# 1406            100%       14:15         11:35
# 1422            100%       15:45         13:15
# 1420             97%       10:20         07:55
# 1621             97%       11:10         08:40
# 1498             97%       21:55         19:25
# 1614             93%       11:45         09:15
# 1427            100%       12:10         09:25
# 1653             97%       11:10         08:40
# 1615             97%       11:10         08:40

# %%
filtered_df0
# Out:
# Empty DataFrame
# Columns: [LowestPrice, Airline, FlightNumber, Legs, PunctualityRate, ArrivalDate, DepartureDate]
# Index: []

# %%
filtered_df = temp_df[temp_df['Legs'].apply(lambda x: any('北京' in leg[:-1] for leg in x))]
display(filtered_df)
# Out:
#     LowestPrice Airline FlightNumber                  Legs PunctualityRate  \
# 0           400    深圳航空       ZH9139    [运城张孝机场, 北京首都国际机场]            100%
# 1           400    深圳航空       ZH9139    [运城张孝机场, 北京首都国际机场]            100%
# 2          3890    上海航空       FM9332  [上海虹桥国际机场, 北京首都国际机场]             77%
# 3          3890    东方航空       MU5338  [上海虹桥国际机场, 北京首都国际机场]             90%
# 4          3550    东方航空       MU5344  [上海虹桥国际机场, 北京大兴国际机场]            100%
# ..          ...     ...          ...                   ...             ...
# 444         450    深圳航空       ZH9115  [北京首都国际机场, 太原武宿国际机场]            100%
# 450         450    中国国航       CA1332  [北京首都国际机场, 太原武宿国际机场]             97%
# 451         450    中国国航       CA3575  [北京首都国际机场, 太原武宿国际机场]            100%
# 452         450    中国国航       CA3405  [北京首都国际机场, 太原武宿国际机场]            100%
# 453         450    中国国航       CA1384  [北京首都国际机场, 太原武宿国际机场]            100%
#
#     ArrivalDate DepartureDate
# 0         11:45         08:55
# 1         11:45         08:55
# 2         14:30         12:30
# 3         13:40         11:30
# 4         16:45         14:30
# ..          ...           ...
# 444       00:45         21:30
# 450       15:55         13:00
# 451       00:45         21:30
# 452       15:45         12:30
# 453       18:10         15:00
#
# [77 rows x 7 columns]

# %%
filtered_df
# Out:
#     LowestPrice Airline FlightNumber                Legs PunctualityRate  \
# 0           400    深圳航空       ZH9139  [运城张孝机场, 北京首都国际机场]            100%
# 1           400    深圳航空       ZH9139  [运城张孝机场, 北京首都国际机场]            100%
# 139         400    深圳航空       ZH9139  [运城张孝机场, 沈阳桃仙国际机场]            100%
#
#     ArrivalDate DepartureDate
# 0         11:45         08:55
# 1         11:45         08:55
# 139       11:45         08:55
